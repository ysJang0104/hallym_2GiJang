# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import MinMaxScaler

directory1 = "apg파일/"
data = []

# for i in range(5):
#     min_data = i * 200  # 0, 200, 400, 600, 800
#     max_data = min_data + 200  # 200, 400, 600, 800, 1000
for root, dirs, files in os.walk(directory1):
#     files.sort()
    for file in files:
        if file.endswith(".csv"):
            full_path = os.path.join(root, file)
            df = pd.read_csv(full_path, usecols=['APG Wave'])
            series = df.values.flatten()[:200]  # max data
            series = series.reshape(-1, 1)  # 1D -> 2D
            scaler = MinMaxScaler()
            series = scaler.fit_transform(series)
            data.append(series)

data_array = np.array(data)

# y를 적절하게 수정 필요 (클래스 불균형 고려)

print("Shape of data_array:", data_array.shape)
# Out:
# Shape of data_array: (130, 200, 1)

# %%
import pandas as pd

# 엑셀 파일 불러오기 (엑셀 파일의 경로를 넣어야 합니다)
df = pd.read_csv("2024-10-11 (11-00-32)-APG【 이기장 】.csv")
df_sorted = df.sort_values(by='TestDate')

# 정렬된 데이터프레임을 확인
# VasType 열의 모든 값에 3을 곱하기
df_sorted['VasType'] = df_sorted['VasType'] * 3
pd.set_option('display.max_rows', None)
# 결과 확인
import pandas as pd

# 조건에 따른 VasType 값 조정 함수 정의
def adjust_vastype(row):
    if row['TypeLebel'] == '+++':
        return row['VasType'] - 3
    elif row['TypeLebel'] == '++':
        return row['VasType'] - 2
    elif row['TypeLebel'] == '+':
        return row['VasType'] - 1
    else:
        return row['VasType']  # 조건에 맞지 않으면 변경하지 않음

# apply 함수로 각 행에 대해 VasType 값을 조정
df_sorted['VasType'] = df_sorted.apply(adjust_vastype, axis=1)

# 결과 확인
pd.set_option('display.max_rows', None)
df_sorted['VasType'].reset_index(drop=True,inplace=True)
df_sorted['VasType'].value_counts()
y = df_sorted['VasType'].values
# y = np.tile(df_sorted['VasType'].values, 5)

# %%
X_flipped = np.flip(data_array, axis=0)

def adjust_amplitude(signal, factor=0.05):
    # signal과 동일한 모양의 랜덤 값을 생성하여 진폭 조정
    return signal * (1 + factor * np.random.uniform(-1, 1, signal.shape))

adjusted_signal = adjust_amplitude(data_array, factor=0.05)
adjusted_signal.shape

X_adjusted=np.vstack((data_array, adjusted_signal))

# 반전 데이터와 원본 데이터 결합
X_augmented = np.vstack((data_array, X_flipped))  # X와 반전 데이터를 위아래로 결합
y_augmented = np.concatenate((y, y)) 

print("Shape of data_array:",adjusted_signal.shape)
# Out:
# Shape of data_array: (130, 200, 1)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import SMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Conv1D, Flatten, BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import KFold
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.layers import Conv1D, Dropout, Flatten, Dense, BatchNormalization, GlobalAveragePooling1D
# Out:
# 2024-11-06 07:11:20.030464: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-06 07:11:20.048666: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-06 07:11:20.069196: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-06 07:11:20.075418: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-06 07:11:20.092369: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-06 07:11:21.254283: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
smote = SMOTE(random_state=42, k_neighbors=2)
X = X_adjusted.reshape(X_adjusted.shape[0], -1)  # (650, 200 * 1) 형태로 변환

X_res, y_res = smote.fit_resample(X, y_augmented)
print(X_res.shape, y_res.shape)
X_train, X_val, y_train, y_val = train_test_split(X_res, y_res, test_size=0.2, random_state=42)
# Out:
# (564, 200) (564,)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # 첫 번째 GPU만 사용

# %%
from sklearn.model_selection import StratifiedKFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)  # 5-fold 교차 검증
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# 클래스 가중치 계산
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(enumerate(class_weights))

# 교차 검증 반복
fold_val_accuracies = []
for fold, (train_idx, val_idx) in enumerate(kf.split(X_train, y_train), 1):
    print(f"Fold {fold}/{skf.get_n_splits()}")

    # 학습과 검증 데이터 분할
    X_train_fold, X_val_fold = X_train[train_idx], X_train[val_idx]
    y_train_fold, y_val_fold = y_train[train_idx], y_train[val_idx]

    # 모델 정의
    model = Sequential([
        Conv1D(32, kernel_size=5, activation='relu', input_shape=(X_train.shape[1], 1)),
        BatchNormalization(),
        Dropout(0.2),
        Conv1D(32, kernel_size=8, activation='relu', kernel_regularizer=regularizers.l2(0.2)),
        BatchNormalization(),
        Dropout(0.1),
        Conv1D(32, kernel_size=10, activation='relu', kernel_regularizer=regularizers.l2(0.3)),
        BatchNormalization(),
        Dropout(0.2),
        Flatten(),
        Dense(32, activation='relu'),
        Dense(18, activation='softmax')
    ])

    # Learning Rate Scheduler
    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

    # 모델 컴파일
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss=SparseCategoricalCrossentropy(),
                  metrics=['accuracy'])

    # 모델 학습
    history = model.fit(
        X_train_fold, y_train_fold,
        validation_data=(X_val_fold, y_val_fold),
        batch_size=4,
        epochs=60,
        class_weight=class_weight_dict,
        callbacks=[lr_scheduler],
        verbose=1
    )

    # 최종 검증 정확도 저장
    val_accuracy = history.history['val_accuracy'][-1]
    fold_val_accuracies.append(val_accuracy)
    print(f"Fold {fold} validation accuracy: {val_accuracy:.2%}")

# 평균 검증 정확도 출력
mean_val_accuracy = np.mean(fold_val_accuracies)
print(f"평균 검증 정확도: {mean_val_accuracy:.2%}")

# 최종 모델 저장 (최고 성능의 모델을 저장)
best_model = model
best_model.save('final_model-2.keras')
print("최종 모델이 'final_model.keras'로 저장되었습니다.")
# Out:
# Fold 1/5
# Epoch 1/60
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - accuracy: 0.3900 - loss: 15.6464 - val_accuracy: 0.2088 - val_loss: 8.5082 - learning_rate: 0.0010
# Epoch 2/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8065 - loss: 5.9177 - val_accuracy: 0.2088 - val_loss: 4.8889 - learning_rate: 0.0010
# Epoch 3/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8344 - loss: 2.6102 - val_accuracy: 0.3407 - val_loss: 3.5611 - learning_rate: 0.0010
# Epoch 4/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9721 - loss: 1.1448 - val_accuracy: 0.2527 - val_loss: 3.2631 - learning_rate: 0.0010
# Epoch 5/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9486 - loss: 0.6488 - val_accuracy: 0.4066 - val_loss: 1.7751 - learning_rate: 0.0010
# Epoch 6/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9845 - loss: 0.3941 - val_accuracy: 0.4396 - val_loss: 1.7688 - learning_rate: 0.0010
# Epoch 7/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9602 - loss: 0.3322 - val_accuracy: 0.8132 - val_loss: 0.9332 - learning_rate: 0.0010
# Epoch 8/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9565 - loss: 0.2587 - val_accuracy: 0.7802 - val_loss: 1.2843 - learning_rate: 0.0010
# Epoch 9/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9354 - loss: 0.4292 - val_accuracy: 0.8352 - val_loss: 1.0438 - learning_rate: 0.0010
# Epoch 10/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9354 - loss: 0.4049 - val_accuracy: 0.6703 - val_loss: 2.9839 - learning_rate: 0.0010
# Epoch 11/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9450 - loss: 0.4341 - val_accuracy: 0.8352 - val_loss: 0.7593 - learning_rate: 0.0010
# Epoch 12/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9829 - loss: 0.1906 - val_accuracy: 0.7802 - val_loss: 1.7920 - learning_rate: 0.0010
# Epoch 13/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9300 - loss: 0.4398 - val_accuracy: 0.8571 - val_loss: 1.4886 - learning_rate: 0.0010
# Epoch 14/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9752 - loss: 0.3359 - val_accuracy: 0.8022 - val_loss: 0.8394 - learning_rate: 0.0010
# Epoch 15/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9857 - loss: 0.1787 - val_accuracy: 0.9011 - val_loss: 0.5520 - learning_rate: 0.0010
# Epoch 16/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9648 - loss: 0.2654 - val_accuracy: 0.8901 - val_loss: 1.1360 - learning_rate: 0.0010
# Epoch 17/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9697 - loss: 0.3139 - val_accuracy: 0.8901 - val_loss: 1.0032 - learning_rate: 0.0010
# Epoch 18/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9548 - loss: 0.3200 - val_accuracy: 0.8462 - val_loss: 1.0629 - learning_rate: 0.0010
# Epoch 19/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9809 - loss: 0.2553 - val_accuracy: 0.8462 - val_loss: 0.6741 - learning_rate: 0.0010
# Epoch 20/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9986 - loss: 0.0806 - val_accuracy: 0.7582 - val_loss: 1.3849 - learning_rate: 0.0010
# Epoch 21/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9565 - loss: 0.3129 - val_accuracy: 0.8901 - val_loss: 1.3107 - learning_rate: 5.0000e-04
# Epoch 22/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.1109 - val_accuracy: 0.8462 - val_loss: 0.5740 - learning_rate: 5.0000e-04
# Epoch 23/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0539 - val_accuracy: 0.6264 - val_loss: 1.0305 - learning_rate: 5.0000e-04
# Epoch 24/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9657 - loss: 0.2437 - val_accuracy: 0.8571 - val_loss: 2.0353 - learning_rate: 5.0000e-04
# Epoch 25/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9987 - loss: 0.1606 - val_accuracy: 0.9121 - val_loss: 0.5271 - learning_rate: 5.0000e-04
# Epoch 26/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9996 - loss: 0.0769 - val_accuracy: 0.7802 - val_loss: 0.6911 - learning_rate: 5.0000e-04
# Epoch 27/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0450 - val_accuracy: 0.6484 - val_loss: 0.9752 - learning_rate: 5.0000e-04
# Epoch 28/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0222 - val_accuracy: 0.5604 - val_loss: 1.2793 - learning_rate: 5.0000e-04
# Epoch 29/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9945 - loss: 0.0335 - val_accuracy: 0.3956 - val_loss: 39.0326 - learning_rate: 5.0000e-04
# Epoch 30/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9827 - loss: 0.3264 - val_accuracy: 0.9011 - val_loss: 1.1946 - learning_rate: 5.0000e-04
# Epoch 31/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9980 - loss: 0.1793 - val_accuracy: 0.8791 - val_loss: 0.9888 - learning_rate: 2.5000e-04
# Epoch 32/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9995 - loss: 0.1261 - val_accuracy: 0.9011 - val_loss: 0.6956 - learning_rate: 2.5000e-04
# Epoch 33/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0884 - val_accuracy: 0.9231 - val_loss: 0.5582 - learning_rate: 2.5000e-04
# Epoch 34/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0614 - val_accuracy: 0.9121 - val_loss: 0.5069 - learning_rate: 2.5000e-04
# Epoch 35/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0422 - val_accuracy: 0.9011 - val_loss: 0.5139 - learning_rate: 2.5000e-04
# Epoch 36/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0302 - val_accuracy: 0.8901 - val_loss: 0.4975 - learning_rate: 2.5000e-04
# Epoch 37/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0221 - val_accuracy: 0.8901 - val_loss: 0.4861 - learning_rate: 2.5000e-04
# Epoch 38/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0159 - val_accuracy: 0.9121 - val_loss: 0.4618 - learning_rate: 2.5000e-04
# Epoch 39/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9971 - loss: 0.0210 - val_accuracy: 0.9011 - val_loss: 1.4791 - learning_rate: 2.5000e-04
# Epoch 40/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9995 - loss: 0.0297 - val_accuracy: 0.8352 - val_loss: 1.5322 - learning_rate: 2.5000e-04
# Epoch 41/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9992 - loss: 0.0428 - val_accuracy: 0.7802 - val_loss: 2.1216 - learning_rate: 2.5000e-04
# Epoch 42/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9812 - loss: 0.0900 - val_accuracy: 0.8791 - val_loss: 0.9092 - learning_rate: 2.5000e-04
# Epoch 43/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9860 - loss: 0.1191 - val_accuracy: 0.9121 - val_loss: 0.7935 - learning_rate: 2.5000e-04
# Epoch 44/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9986 - loss: 0.0470 - val_accuracy: 0.9121 - val_loss: 0.6204 - learning_rate: 1.2500e-04
# Epoch 45/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0370 - val_accuracy: 0.9121 - val_loss: 0.6093 - learning_rate: 1.2500e-04
# Epoch 46/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0290 - val_accuracy: 0.9121 - val_loss: 0.6089 - learning_rate: 1.2500e-04
# Epoch 47/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0225 - val_accuracy: 0.9231 - val_loss: 0.5919 - learning_rate: 1.2500e-04
# Epoch 48/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0175 - val_accuracy: 0.9231 - val_loss: 0.5699 - learning_rate: 1.2500e-04
# Epoch 49/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0148 - val_accuracy: 0.9121 - val_loss: 0.6333 - learning_rate: 6.2500e-05
# Epoch 50/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0128 - val_accuracy: 0.9121 - val_loss: 0.6903 - learning_rate: 6.2500e-05
# Epoch 51/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.9121 - val_loss: 0.6949 - learning_rate: 6.2500e-05
# Epoch 52/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.9121 - val_loss: 0.6929 - learning_rate: 6.2500e-05
# Epoch 53/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.9121 - val_loss: 0.7082 - learning_rate: 6.2500e-05
# Epoch 54/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.9121 - val_loss: 0.7312 - learning_rate: 3.1250e-05
# Epoch 55/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.9121 - val_loss: 0.7293 - learning_rate: 3.1250e-05
# Epoch 56/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.9121 - val_loss: 0.8198 - learning_rate: 3.1250e-05
# Epoch 57/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.9121 - val_loss: 0.7963 - learning_rate: 3.1250e-05
# Epoch 58/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.9121 - val_loss: 0.7971 - learning_rate: 3.1250e-05
# Epoch 59/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9121 - val_loss: 0.7899 - learning_rate: 1.5625e-05
# Epoch 60/60
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9121 - val_loss: 0.7895 - learning_rate: 1.5625e-05
# Fold 1 validation accuracy: 91.21%
# Fold 2/5
# Epoch 1/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 13s 72ms/step - accuracy: 0.3929 - loss: 15.7412 - val_accuracy: 0.1000 - val_loss: 10.1996 - learning_rate: 0.0010
# Epoch 2/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7872 - loss: 6.5402 - val_accuracy: 0.1111 - val_loss: 7.0821 - learning_rate: 0.0010
# Epoch 3/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8300 - loss: 3.5074 - val_accuracy: 0.1000 - val_loss: 6.4515 - learning_rate: 0.0010
# Epoch 4/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9136 - loss: 1.9710 - val_accuracy: 0.2667 - val_loss: 4.4345 - learning_rate: 0.0010
# Epoch 5/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9119 - loss: 1.2631 - val_accuracy: 0.2000 - val_loss: 3.5655 - learning_rate: 0.0010
# Epoch 6/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9554 - loss: 0.7824 - val_accuracy: 0.3222 - val_loss: 2.0567 - learning_rate: 0.0010
# Epoch 7/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9780 - loss: 0.4647 - val_accuracy: 0.7333 - val_loss: 0.9554 - learning_rate: 0.0010
# Epoch 8/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9787 - loss: 0.3570 - val_accuracy: 0.8222 - val_loss: 1.0611 - learning_rate: 0.0010
# Epoch 9/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9394 - loss: 0.5329 - val_accuracy: 0.8111 - val_loss: 1.0897 - learning_rate: 0.0010
# Epoch 10/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9658 - loss: 0.3565 - val_accuracy: 0.9222 - val_loss: 0.5469 - learning_rate: 0.0010
# Epoch 11/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9701 - loss: 0.3125 - val_accuracy: 0.9556 - val_loss: 0.6213 - learning_rate: 0.0010
# Epoch 12/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9723 - loss: 0.4479 - val_accuracy: 0.7444 - val_loss: 0.9808 - learning_rate: 0.0010
# Epoch 13/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9717 - loss: 0.2948 - val_accuracy: 0.7333 - val_loss: 1.1419 - learning_rate: 0.0010
# Epoch 14/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9800 - loss: 0.1928 - val_accuracy: 0.9333 - val_loss: 0.4375 - learning_rate: 0.0010
# Epoch 15/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9838 - loss: 0.2267 - val_accuracy: 0.9000 - val_loss: 0.5403 - learning_rate: 0.0010
# Epoch 16/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.1001 - val_accuracy: 0.3556 - val_loss: 2.4674 - learning_rate: 0.0010
# Epoch 17/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0342 - val_accuracy: 0.1778 - val_loss: 3.5883 - learning_rate: 0.0010
# Epoch 18/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0174 - val_accuracy: 0.9222 - val_loss: 0.6832 - learning_rate: 0.0010
# Epoch 19/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9935 - loss: 0.1059 - val_accuracy: 0.8222 - val_loss: 1.2928 - learning_rate: 0.0010
# Epoch 20/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9972 - loss: 0.1280 - val_accuracy: 0.8444 - val_loss: 1.0139 - learning_rate: 5.0000e-04
# Epoch 21/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9763 - loss: 0.1748 - val_accuracy: 0.9444 - val_loss: 0.3306 - learning_rate: 5.0000e-04
# Epoch 22/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0740 - val_accuracy: 0.8444 - val_loss: 0.6065 - learning_rate: 5.0000e-04
# Epoch 23/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0457 - val_accuracy: 0.7222 - val_loss: 0.7931 - learning_rate: 5.0000e-04
# Epoch 24/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0237 - val_accuracy: 0.5333 - val_loss: 1.1640 - learning_rate: 5.0000e-04
# Epoch 25/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0133 - val_accuracy: 0.5222 - val_loss: 0.9996 - learning_rate: 5.0000e-04
# Epoch 26/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 0.9333 - val_loss: 0.3195 - learning_rate: 5.0000e-04
# Epoch 27/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.9444 - val_loss: 0.2619 - learning_rate: 5.0000e-04
# Epoch 28/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 0.9333 - val_loss: 0.4789 - learning_rate: 5.0000e-04
# Epoch 29/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9951 - loss: 0.0425 - val_accuracy: 0.6333 - val_loss: 4.5637 - learning_rate: 5.0000e-04
# Epoch 30/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9986 - loss: 0.1266 - val_accuracy: 0.8889 - val_loss: 0.6933 - learning_rate: 5.0000e-04
# Epoch 31/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9864 - loss: 0.1338 - val_accuracy: 0.9333 - val_loss: 0.6472 - learning_rate: 5.0000e-04
# Epoch 32/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9763 - loss: 0.2107 - val_accuracy: 0.8667 - val_loss: 0.6919 - learning_rate: 5.0000e-04
# Epoch 33/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9864 - loss: 0.1760 - val_accuracy: 0.9556 - val_loss: 0.4592 - learning_rate: 2.5000e-04
# Epoch 34/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.1060 - val_accuracy: 0.9444 - val_loss: 0.3734 - learning_rate: 2.5000e-04
# Epoch 35/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0688 - val_accuracy: 0.9111 - val_loss: 0.3665 - learning_rate: 2.5000e-04
# Epoch 36/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0462 - val_accuracy: 0.8667 - val_loss: 0.4069 - learning_rate: 2.5000e-04
# Epoch 37/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0310 - val_accuracy: 0.8556 - val_loss: 0.4444 - learning_rate: 2.5000e-04
# Epoch 38/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0219 - val_accuracy: 0.9000 - val_loss: 0.3382 - learning_rate: 1.2500e-04
# Epoch 39/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0187 - val_accuracy: 0.9444 - val_loss: 0.3264 - learning_rate: 1.2500e-04
# Epoch 40/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0155 - val_accuracy: 0.9444 - val_loss: 0.3428 - learning_rate: 1.2500e-04
# Epoch 41/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 0.9333 - val_loss: 0.3426 - learning_rate: 1.2500e-04
# Epoch 42/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.9333 - val_loss: 0.3345 - learning_rate: 1.2500e-04
# Epoch 43/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.9444 - val_loss: 0.3515 - learning_rate: 6.2500e-05
# Epoch 44/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.9444 - val_loss: 0.3569 - learning_rate: 6.2500e-05
# Epoch 45/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.9444 - val_loss: 0.3523 - learning_rate: 6.2500e-05
# Epoch 46/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.9444 - val_loss: 0.3553 - learning_rate: 6.2500e-05
# Epoch 47/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.9444 - val_loss: 0.3546 - learning_rate: 6.2500e-05
# Epoch 48/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.9444 - val_loss: 0.3732 - learning_rate: 3.1250e-05
# Epoch 49/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.9333 - val_loss: 0.3758 - learning_rate: 3.1250e-05
# Epoch 50/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.9333 - val_loss: 0.3720 - learning_rate: 3.1250e-05
# Epoch 51/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.9444 - val_loss: 0.3710 - learning_rate: 3.1250e-05
# Epoch 52/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9333 - val_loss: 0.3673 - learning_rate: 3.1250e-05
# Epoch 53/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.9333 - val_loss: 0.3690 - learning_rate: 1.5625e-05
# Epoch 54/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9444 - val_loss: 0.3744 - learning_rate: 1.5625e-05
# Epoch 55/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9444 - val_loss: 0.3775 - learning_rate: 1.5625e-05
# Epoch 56/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9444 - val_loss: 0.3733 - learning_rate: 1.5625e-05
# Epoch 57/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.9444 - val_loss: 0.3746 - learning_rate: 1.5625e-05
# Epoch 58/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.9444 - val_loss: 0.3786 - learning_rate: 7.8125e-06
# Epoch 59/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.9444 - val_loss: 0.3751 - learning_rate: 7.8125e-06
# Epoch 60/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9333 - val_loss: 0.3691 - learning_rate: 7.8125e-06
# Fold 2 validation accuracy: 93.33%
# Fold 3/5
# Epoch 1/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 13s 73ms/step - accuracy: 0.3207 - loss: 15.4280 - val_accuracy: 0.2111 - val_loss: 7.9480 - learning_rate: 0.0010
# Epoch 2/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7776 - loss: 5.7165 - val_accuracy: 0.2111 - val_loss: 4.3859 - learning_rate: 0.0010
# Epoch 3/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8360 - loss: 2.7296 - val_accuracy: 0.2333 - val_loss: 3.0243 - learning_rate: 0.0010
# Epoch 4/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8992 - loss: 1.3396 - val_accuracy: 0.2444 - val_loss: 2.6588 - learning_rate: 0.0010
# Epoch 5/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9678 - loss: 0.6783 - val_accuracy: 0.6667 - val_loss: 1.1707 - learning_rate: 0.0010
# Epoch 6/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9645 - loss: 0.5005 - val_accuracy: 0.8333 - val_loss: 0.8023 - learning_rate: 0.0010
# Epoch 7/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9784 - loss: 0.3262 - val_accuracy: 0.9222 - val_loss: 0.4993 - learning_rate: 0.0010
# Epoch 8/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9399 - loss: 0.4072 - val_accuracy: 0.9000 - val_loss: 0.8777 - learning_rate: 0.0010
# Epoch 9/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9646 - loss: 0.3829 - val_accuracy: 0.9111 - val_loss: 0.5396 - learning_rate: 0.0010
# Epoch 10/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9615 - loss: 0.2935 - val_accuracy: 0.9444 - val_loss: 0.3901 - learning_rate: 0.0010
# Epoch 11/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9664 - loss: 0.2604 - val_accuracy: 0.8889 - val_loss: 0.7662 - learning_rate: 0.0010
# Epoch 12/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9641 - loss: 0.3265 - val_accuracy: 0.8444 - val_loss: 1.2479 - learning_rate: 0.0010
# Epoch 13/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9626 - loss: 0.3696 - val_accuracy: 0.7222 - val_loss: 1.4003 - learning_rate: 0.0010
# Epoch 14/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9445 - loss: 0.4396 - val_accuracy: 0.9222 - val_loss: 0.4651 - learning_rate: 0.0010
# Epoch 15/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9858 - loss: 0.2027 - val_accuracy: 0.9333 - val_loss: 0.5841 - learning_rate: 0.0010
# Epoch 16/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9894 - loss: 0.2217 - val_accuracy: 0.9333 - val_loss: 0.5476 - learning_rate: 5.0000e-04
# Epoch 17/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9981 - loss: 0.1548 - val_accuracy: 0.9333 - val_loss: 0.4706 - learning_rate: 5.0000e-04
# Epoch 18/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9926 - loss: 0.1319 - val_accuracy: 0.9333 - val_loss: 0.3256 - learning_rate: 5.0000e-04
# Epoch 19/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0651 - val_accuracy: 0.8889 - val_loss: 0.3866 - learning_rate: 5.0000e-04
# Epoch 20/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0372 - val_accuracy: 0.8000 - val_loss: 0.5605 - learning_rate: 5.0000e-04
# Epoch 21/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0255 - val_accuracy: 0.9333 - val_loss: 0.2985 - learning_rate: 5.0000e-04
# Epoch 22/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9948 - loss: 0.0576 - val_accuracy: 0.9000 - val_loss: 1.6738 - learning_rate: 5.0000e-04
# Epoch 23/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9912 - loss: 0.1475 - val_accuracy: 0.9444 - val_loss: 0.3310 - learning_rate: 5.0000e-04
# Epoch 24/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9997 - loss: 0.0716 - val_accuracy: 0.8889 - val_loss: 0.4262 - learning_rate: 5.0000e-04
# Epoch 25/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9556 - loss: 0.3012 - val_accuracy: 0.9111 - val_loss: 0.9332 - learning_rate: 5.0000e-04
# Epoch 26/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9914 - loss: 0.2313 - val_accuracy: 0.9444 - val_loss: 0.3903 - learning_rate: 5.0000e-04
# Epoch 27/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0918 - val_accuracy: 0.9444 - val_loss: 0.3217 - learning_rate: 2.5000e-04
# Epoch 28/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0614 - val_accuracy: 0.9444 - val_loss: 0.2973 - learning_rate: 2.5000e-04
# Epoch 29/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0420 - val_accuracy: 0.9444 - val_loss: 0.2768 - learning_rate: 2.5000e-04
# Epoch 30/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0280 - val_accuracy: 0.9444 - val_loss: 0.2752 - learning_rate: 2.5000e-04
# Epoch 31/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0192 - val_accuracy: 0.9444 - val_loss: 0.2823 - learning_rate: 2.5000e-04
# Epoch 32/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 0.9444 - val_loss: 0.2417 - learning_rate: 2.5000e-04
# Epoch 33/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 0.9444 - val_loss: 0.2373 - learning_rate: 2.5000e-04
# Epoch 34/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.9333 - val_loss: 0.2807 - learning_rate: 2.5000e-04
# Epoch 35/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.9444 - val_loss: 0.2830 - learning_rate: 2.5000e-04
# Epoch 36/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.9333 - val_loss: 0.4536 - learning_rate: 2.5000e-04
# Epoch 37/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.9333 - val_loss: 0.3442 - learning_rate: 2.5000e-04
# Epoch 38/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9906 - loss: 0.0379 - val_accuracy: 0.8444 - val_loss: 2.7004 - learning_rate: 2.5000e-04
# Epoch 39/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9861 - loss: 0.1076 - val_accuracy: 0.9444 - val_loss: 0.6094 - learning_rate: 1.2500e-04
# Epoch 40/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0508 - val_accuracy: 0.9444 - val_loss: 0.3967 - learning_rate: 1.2500e-04
# Epoch 41/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0379 - val_accuracy: 0.9444 - val_loss: 0.3296 - learning_rate: 1.2500e-04
# Epoch 42/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0284 - val_accuracy: 0.9444 - val_loss: 0.3104 - learning_rate: 1.2500e-04
# Epoch 43/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0230 - val_accuracy: 0.9444 - val_loss: 0.2937 - learning_rate: 1.2500e-04
# Epoch 44/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0173 - val_accuracy: 0.9444 - val_loss: 0.3150 - learning_rate: 6.2500e-05
# Epoch 45/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 0.9444 - val_loss: 0.3255 - learning_rate: 6.2500e-05
# Epoch 46/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0136 - val_accuracy: 0.9444 - val_loss: 0.3358 - learning_rate: 6.2500e-05
# Epoch 47/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.9444 - val_loss: 0.3159 - learning_rate: 6.2500e-05
# Epoch 48/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.9444 - val_loss: 0.3194 - learning_rate: 6.2500e-05
# Epoch 49/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.9444 - val_loss: 0.3276 - learning_rate: 3.1250e-05
# Epoch 50/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.9444 - val_loss: 0.3283 - learning_rate: 3.1250e-05
# Epoch 51/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.9444 - val_loss: 0.3262 - learning_rate: 3.1250e-05
# Epoch 52/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.9444 - val_loss: 0.3278 - learning_rate: 3.1250e-05
# Epoch 53/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.9444 - val_loss: 0.3277 - learning_rate: 3.1250e-05
# Epoch 54/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.9444 - val_loss: 0.3411 - learning_rate: 1.5625e-05
# Epoch 55/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9444 - val_loss: 0.3381 - learning_rate: 1.5625e-05
# Epoch 56/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.9444 - val_loss: 0.3398 - learning_rate: 1.5625e-05
# Epoch 57/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9444 - val_loss: 0.3352 - learning_rate: 1.5625e-05
# Epoch 58/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.9444 - val_loss: 0.3529 - learning_rate: 1.5625e-05
# Epoch 59/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.9444 - val_loss: 0.3511 - learning_rate: 7.8125e-06
# Epoch 60/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.9444 - val_loss: 0.3468 - learning_rate: 7.8125e-06
# Fold 3 validation accuracy: 94.44%
# Fold 4/5
# Epoch 1/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 13s 71ms/step - accuracy: 0.3749 - loss: 15.6250 - val_accuracy: 0.2333 - val_loss: 8.8986 - learning_rate: 0.0010
# Epoch 2/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8170 - loss: 5.9959 - val_accuracy: 0.2111 - val_loss: 5.0730 - learning_rate: 0.0010
# Epoch 3/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8759 - loss: 2.6551 - val_accuracy: 0.2111 - val_loss: 3.4424 - learning_rate: 0.0010
# Epoch 4/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8979 - loss: 1.3106 - val_accuracy: 0.3000 - val_loss: 2.8643 - learning_rate: 0.0010
# Epoch 5/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9702 - loss: 0.6457 - val_accuracy: 0.4000 - val_loss: 1.9903 - learning_rate: 0.0010
# Epoch 6/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9248 - loss: 0.5866 - val_accuracy: 0.8333 - val_loss: 1.0420 - learning_rate: 0.0010
# Epoch 7/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9714 - loss: 0.3379 - val_accuracy: 0.8778 - val_loss: 0.8535 - learning_rate: 0.0010
# Epoch 8/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9734 - loss: 0.2958 - val_accuracy: 0.9111 - val_loss: 0.7208 - learning_rate: 0.0010
# Epoch 9/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9714 - loss: 0.2410 - val_accuracy: 0.9111 - val_loss: 0.9757 - learning_rate: 0.0010
# Epoch 10/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9869 - loss: 0.2132 - val_accuracy: 0.8889 - val_loss: 0.6432 - learning_rate: 0.0010
# Epoch 11/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9414 - loss: 0.4419 - val_accuracy: 0.8222 - val_loss: 3.0079 - learning_rate: 0.0010
# Epoch 12/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9648 - loss: 0.5859 - val_accuracy: 0.8222 - val_loss: 0.8945 - learning_rate: 0.0010
# Epoch 13/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9772 - loss: 0.2935 - val_accuracy: 0.9111 - val_loss: 0.7873 - learning_rate: 0.0010
# Epoch 14/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9689 - loss: 0.3534 - val_accuracy: 0.8556 - val_loss: 0.8468 - learning_rate: 0.0010
# Epoch 15/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9770 - loss: 0.2730 - val_accuracy: 0.8000 - val_loss: 0.9302 - learning_rate: 0.0010
# Epoch 16/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9873 - loss: 0.1360 - val_accuracy: 0.8889 - val_loss: 0.7137 - learning_rate: 5.0000e-04
# Epoch 17/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9810 - loss: 0.1711 - val_accuracy: 0.9111 - val_loss: 0.9124 - learning_rate: 5.0000e-04
# Epoch 18/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9988 - loss: 0.0906 - val_accuracy: 0.9000 - val_loss: 0.7013 - learning_rate: 5.0000e-04
# Epoch 19/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9998 - loss: 0.0516 - val_accuracy: 0.8556 - val_loss: 0.6317 - learning_rate: 5.0000e-04
# Epoch 20/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9910 - loss: 0.0876 - val_accuracy: 0.9222 - val_loss: 0.8110 - learning_rate: 5.0000e-04
# Epoch 21/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9880 - loss: 0.1382 - val_accuracy: 0.9111 - val_loss: 1.0963 - learning_rate: 5.0000e-04
# Epoch 22/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9899 - loss: 0.1270 - val_accuracy: 0.9222 - val_loss: 1.6165 - learning_rate: 5.0000e-04
# Epoch 23/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9953 - loss: 0.1335 - val_accuracy: 0.9111 - val_loss: 0.7180 - learning_rate: 5.0000e-04
# Epoch 24/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0584 - val_accuracy: 0.8667 - val_loss: 0.7000 - learning_rate: 5.0000e-04
# Epoch 25/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9923 - loss: 0.0415 - val_accuracy: 0.9000 - val_loss: 0.7721 - learning_rate: 2.5000e-04
# Epoch 26/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0306 - val_accuracy: 0.9000 - val_loss: 0.7177 - learning_rate: 2.5000e-04
# Epoch 27/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0202 - val_accuracy: 0.9111 - val_loss: 0.6867 - learning_rate: 2.5000e-04
# Epoch 28/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 0.9111 - val_loss: 0.6221 - learning_rate: 2.5000e-04
# Epoch 29/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9873 - loss: 0.0371 - val_accuracy: 0.8667 - val_loss: 1.5506 - learning_rate: 2.5000e-04
# Epoch 30/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9766 - loss: 0.1079 - val_accuracy: 0.9222 - val_loss: 1.0963 - learning_rate: 2.5000e-04
# Epoch 31/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9892 - loss: 0.0901 - val_accuracy: 0.9222 - val_loss: 0.8196 - learning_rate: 2.5000e-04
# Epoch 32/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9964 - loss: 0.0578 - val_accuracy: 0.9444 - val_loss: 0.5808 - learning_rate: 2.5000e-04
# Epoch 33/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0392 - val_accuracy: 0.9444 - val_loss: 0.5388 - learning_rate: 2.5000e-04
# Epoch 34/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0272 - val_accuracy: 0.9333 - val_loss: 0.5412 - learning_rate: 2.5000e-04
# Epoch 35/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0209 - val_accuracy: 0.9333 - val_loss: 0.5398 - learning_rate: 2.5000e-04
# Epoch 36/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 0.9111 - val_loss: 0.6002 - learning_rate: 2.5000e-04
# Epoch 37/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9987 - loss: 0.0142 - val_accuracy: 0.9000 - val_loss: 2.1684 - learning_rate: 2.5000e-04
# Epoch 38/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9726 - loss: 0.1401 - val_accuracy: 0.9222 - val_loss: 1.1412 - learning_rate: 2.5000e-04
# Epoch 39/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0443 - val_accuracy: 0.9333 - val_loss: 0.8544 - learning_rate: 1.2500e-04
# Epoch 40/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0339 - val_accuracy: 0.9333 - val_loss: 0.7448 - learning_rate: 1.2500e-04
# Epoch 41/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0265 - val_accuracy: 0.9222 - val_loss: 0.7089 - learning_rate: 1.2500e-04
# Epoch 42/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0210 - val_accuracy: 0.9222 - val_loss: 0.6904 - learning_rate: 1.2500e-04
# Epoch 43/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0173 - val_accuracy: 0.9222 - val_loss: 0.6724 - learning_rate: 1.2500e-04
# Epoch 44/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0138 - val_accuracy: 0.9222 - val_loss: 0.7777 - learning_rate: 6.2500e-05
# Epoch 45/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0128 - val_accuracy: 0.9222 - val_loss: 0.8160 - learning_rate: 6.2500e-05
# Epoch 46/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.9222 - val_loss: 0.8128 - learning_rate: 6.2500e-05
# Epoch 47/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.9222 - val_loss: 0.8298 - learning_rate: 6.2500e-05
# Epoch 48/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.9222 - val_loss: 0.8048 - learning_rate: 6.2500e-05
# Epoch 49/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.9222 - val_loss: 0.8355 - learning_rate: 3.1250e-05
# Epoch 50/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.9222 - val_loss: 0.8479 - learning_rate: 3.1250e-05
# Epoch 51/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.9222 - val_loss: 0.8347 - learning_rate: 3.1250e-05
# Epoch 52/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.9222 - val_loss: 0.8608 - learning_rate: 3.1250e-05
# Epoch 53/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.9222 - val_loss: 0.9051 - learning_rate: 3.1250e-05
# Epoch 54/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.9222 - val_loss: 0.9011 - learning_rate: 1.5625e-05
# Epoch 55/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9222 - val_loss: 0.9009 - learning_rate: 1.5625e-05
# Epoch 56/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.9222 - val_loss: 0.9118 - learning_rate: 1.5625e-05
# Epoch 57/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9222 - val_loss: 0.9231 - learning_rate: 1.5625e-05
# Epoch 58/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.9222 - val_loss: 0.9033 - learning_rate: 1.5625e-05
# Epoch 59/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9222 - val_loss: 0.9018 - learning_rate: 7.8125e-06
# Epoch 60/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.9222 - val_loss: 0.8983 - learning_rate: 7.8125e-06
# Fold 4 validation accuracy: 92.22%
# Fold 5/5
# Epoch 1/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 13s 72ms/step - accuracy: 0.3608 - loss: 15.9196 - val_accuracy: 0.1111 - val_loss: 9.8900 - learning_rate: 0.0010
# Epoch 2/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7104 - loss: 7.0279 - val_accuracy: 0.1111 - val_loss: 5.9050 - learning_rate: 0.0010
# Epoch 3/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8313 - loss: 3.6688 - val_accuracy: 0.1111 - val_loss: 5.8487 - learning_rate: 0.0010
# Epoch 4/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9384 - loss: 1.7425 - val_accuracy: 0.1111 - val_loss: 4.1891 - learning_rate: 0.0010
# Epoch 5/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9749 - loss: 0.8641 - val_accuracy: 0.6111 - val_loss: 1.5692 - learning_rate: 0.0010
# Epoch 6/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9195 - loss: 0.7926 - val_accuracy: 0.6667 - val_loss: 1.4087 - learning_rate: 0.0010
# Epoch 7/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9726 - loss: 0.4647 - val_accuracy: 0.9444 - val_loss: 0.5500 - learning_rate: 0.0010
# Epoch 8/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9570 - loss: 0.3824 - val_accuracy: 0.9667 - val_loss: 0.4540 - learning_rate: 0.0010
# Epoch 9/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9708 - loss: 0.3327 - val_accuracy: 0.8778 - val_loss: 0.6915 - learning_rate: 0.0010
# Epoch 10/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9580 - loss: 0.4294 - val_accuracy: 0.9667 - val_loss: 0.4853 - learning_rate: 0.0010
# Epoch 11/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9470 - loss: 0.4010 - val_accuracy: 0.9444 - val_loss: 0.4312 - learning_rate: 0.0010
# Epoch 12/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9688 - loss: 0.2698 - val_accuracy: 0.9333 - val_loss: 0.8958 - learning_rate: 0.0010
# Epoch 13/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9486 - loss: 0.5674 - val_accuracy: 0.9444 - val_loss: 0.4921 - learning_rate: 0.0010
# Epoch 14/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9962 - loss: 0.2421 - val_accuracy: 0.8556 - val_loss: 0.9740 - learning_rate: 0.0010
# Epoch 15/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9460 - loss: 0.5819 - val_accuracy: 0.9333 - val_loss: 0.4784 - learning_rate: 0.0010
# Epoch 16/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9843 - loss: 0.2846 - val_accuracy: 0.9000 - val_loss: 0.5678 - learning_rate: 0.0010
# Epoch 17/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9688 - loss: 0.4590 - val_accuracy: 0.9778 - val_loss: 0.3084 - learning_rate: 5.0000e-04
# Epoch 18/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9935 - loss: 0.1249 - val_accuracy: 0.9333 - val_loss: 0.2638 - learning_rate: 5.0000e-04
# Epoch 19/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0670 - val_accuracy: 0.9000 - val_loss: 0.3285 - learning_rate: 5.0000e-04
# Epoch 20/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0376 - val_accuracy: 0.9111 - val_loss: 0.3109 - learning_rate: 5.0000e-04
# Epoch 21/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9955 - loss: 0.0404 - val_accuracy: 0.9556 - val_loss: 0.4301 - learning_rate: 5.0000e-04
# Epoch 22/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0533 - val_accuracy: 0.9778 - val_loss: 0.2056 - learning_rate: 5.0000e-04
# Epoch 23/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0272 - val_accuracy: 0.8667 - val_loss: 0.2857 - learning_rate: 5.0000e-04
# Epoch 24/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 0.9222 - val_loss: 0.2639 - learning_rate: 5.0000e-04
# Epoch 25/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9985 - loss: 0.0161 - val_accuracy: 0.7000 - val_loss: 6.8429 - learning_rate: 5.0000e-04
# Epoch 26/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9760 - loss: 0.2507 - val_accuracy: 0.9444 - val_loss: 0.7383 - learning_rate: 5.0000e-04
# Epoch 27/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9646 - loss: 0.2156 - val_accuracy: 0.9667 - val_loss: 0.2615 - learning_rate: 5.0000e-04
# Epoch 28/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0831 - val_accuracy: 0.9778 - val_loss: 0.2022 - learning_rate: 2.5000e-04
# Epoch 29/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0564 - val_accuracy: 0.9444 - val_loss: 0.1979 - learning_rate: 2.5000e-04
# Epoch 30/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0380 - val_accuracy: 0.9444 - val_loss: 0.1905 - learning_rate: 2.5000e-04
# Epoch 31/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0263 - val_accuracy: 0.9556 - val_loss: 0.1606 - learning_rate: 2.5000e-04
# Epoch 32/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0207 - val_accuracy: 0.9556 - val_loss: 0.1230 - learning_rate: 2.5000e-04
# Epoch 33/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0145 - val_accuracy: 0.9556 - val_loss: 0.1242 - learning_rate: 2.5000e-04
# Epoch 34/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 0.9667 - val_loss: 0.1240 - learning_rate: 2.5000e-04
# Epoch 35/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9977 - loss: 0.0245 - val_accuracy: 0.9111 - val_loss: 1.0145 - learning_rate: 2.5000e-04
# Epoch 36/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9889 - loss: 0.0866 - val_accuracy: 0.9778 - val_loss: 0.3848 - learning_rate: 2.5000e-04
# Epoch 37/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9988 - loss: 0.0705 - val_accuracy: 0.9667 - val_loss: 0.1965 - learning_rate: 2.5000e-04
# Epoch 38/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0522 - val_accuracy: 0.9778 - val_loss: 0.1608 - learning_rate: 1.2500e-04
# Epoch 39/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0407 - val_accuracy: 0.9778 - val_loss: 0.1460 - learning_rate: 1.2500e-04
# Epoch 40/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0320 - val_accuracy: 0.9667 - val_loss: 0.1317 - learning_rate: 1.2500e-04
# Epoch 41/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0250 - val_accuracy: 0.9556 - val_loss: 0.1250 - learning_rate: 1.2500e-04
# Epoch 42/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0196 - val_accuracy: 0.9556 - val_loss: 0.1232 - learning_rate: 1.2500e-04
# Epoch 43/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0164 - val_accuracy: 0.9667 - val_loss: 0.1344 - learning_rate: 6.2500e-05
# Epoch 44/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.9667 - val_loss: 0.1415 - learning_rate: 6.2500e-05
# Epoch 45/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0142 - val_accuracy: 0.9667 - val_loss: 0.1335 - learning_rate: 6.2500e-05
# Epoch 46/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0114 - val_accuracy: 0.9667 - val_loss: 0.1311 - learning_rate: 6.2500e-05
# Epoch 47/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 0.9667 - val_loss: 0.1286 - learning_rate: 6.2500e-05
# Epoch 48/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.9667 - val_loss: 0.1365 - learning_rate: 3.1250e-05
# Epoch 49/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.9667 - val_loss: 0.1473 - learning_rate: 3.1250e-05
# Epoch 50/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 0.9667 - val_loss: 0.1560 - learning_rate: 3.1250e-05
# Epoch 51/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.9667 - val_loss: 0.1544 - learning_rate: 3.1250e-05
# Epoch 52/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.9667 - val_loss: 0.1510 - learning_rate: 3.1250e-05
# Epoch 53/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.9667 - val_loss: 0.1582 - learning_rate: 1.5625e-05
# Epoch 54/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.9667 - val_loss: 0.1593 - learning_rate: 1.5625e-05
# Epoch 55/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9667 - val_loss: 0.1601 - learning_rate: 1.5625e-05
# Epoch 56/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.9667 - val_loss: 0.1592 - learning_rate: 1.5625e-05
# Epoch 57/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.9667 - val_loss: 0.1604 - learning_rate: 1.5625e-05
# Epoch 58/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.9667 - val_loss: 0.1682 - learning_rate: 7.8125e-06
# Epoch 59/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.9667 - val_loss: 0.1676 - learning_rate: 7.8125e-06
# Epoch 60/60
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9667 - val_loss: 0.1669 - learning_rate: 7.8125e-06
# Fold 5 validation accuracy: 96.67%
# 평균 검증 정확도: 93.58%
# 최종 모델이 'final_model.keras'로 저장되었습니다.

# %%
# !nvidia-smi
# Out:
# Wed Nov  6 11:56:47 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 555.42.02              Driver Version: 555.42.02      CUDA Version: 12.5     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3090        Off |   00000000:23:00.0 Off |                  N/A |
# | 33%   28C    P8             21W /  350W |   23988MiB /  24576MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA GeForce RTX 3090        Off |   00000000:24:00.0 Off |                  N/A |
# | 37%   48C    P0            117W /  350W |   22791MiB /  24576MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
from tensorflow.keras.models import load_model

# 모델 로드
loaded_model = load_model('final_model.keras')

# 모델 요약 보기 (선택 사항)
loaded_model.summary()
# Out:
# Model: "sequential_19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_38 (Conv1D)              │ (None, 198, 64)        │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_38          │ (None, 198, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_57 (Dropout)            │ (None, 198, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_39 (Conv1D)              │ (None, 196, 64)        │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_39          │ (None, 196, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_58 (Dropout)            │ (None, 196, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_19 (Flatten)            │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_38 (Dense)                │ (None, 64)             │       802,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_59 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_39 (Dense)                │ (None, 18)             │         1,170 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,451,000 (9.35 MB)
#  Trainable params: 816,914 (3.12 MB)
#  Non-trainable params: 256 (1.00 KB)
#  Optimizer params: 1,633,830 (6.23 MB)
